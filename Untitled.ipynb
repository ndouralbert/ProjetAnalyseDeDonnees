# %%
import matplotlib.pyplot as plt

# Données
marqueurs = [
    'ATP6', 'COX1', 'COX1', 'COX2', 'COX3', 'COX3', 
    'CYTB', 'CYTB', 'NADH1', 'NADH2', 'NADH3', 
    'NADH4', 'NADH4L', 'NADH4L', 'NADH5', 'NADH6',
    'NADH6', 'NADH6'
]

# p-distances et distances de Poisson
p_distances = [
    0.451, 0.122, 0.122, 0.288, 0.196, 0.194, 
    0.248, 0.248, 0.255, 0.468, 0.329, 
    0.363, 0.453, 0.453, 0.346, 0.363,
    0.363, 0.429851
]

poisson_distances = [
    0.611, 0.131, 0.131, 0.343, 0.220, 0.216,
    0.285, 0.288, 0.297, 0.644, 0.403,
    0.458, 0.615, 0.615, 0.430, 0.458,
    0.458, 0.722354
]

# Création du graphique
plt.figure(figsize=(10, 8))
plt.scatter(poisson_distances, p_distances)

# Tracer la ligne y = x
max_val = max(max(p_distances), max(poisson_distances))
plt.plot([0, max_val], [0, max_val], color='red', linestyle='--')

# Ajouter des labels et un titre
plt.title('Comparaison des distances évolutives')
plt.xlabel('Distance de Poisson')
plt.ylabel('p-distance')
plt.xlim(0, max_val)
plt.ylim(0, max_val)

# Ajouter des annotations pour chaque marqueur
for i in range(len(marqueurs)):
    plt.annotate(marqueurs[i], (poisson_distances[i], p_distances[i]), fontsize=9)

# Afficher le graphique
plt.grid()
plt.show()
enregistrer

# %%
import matplotlib.pyplot as plt

# Données
marqueurs = [
    'ATP6', 'COX1', 'COX1', 'COX2', 'COX3', 'COX3', 
    'CYTB', 'CYTB', 'NADH1', 'NADH2', 'NADH3', 
    'NADH4', 'NADH4L', 'NADH4L', 'NADH5', 'NADH6',
    'NADH6', 'NADH6'
]

# p-distances et distances de Poisson
p_distances = [
    0.451, 0.122, 0.122, 0.288, 0.196, 0.194, 
    0.248, 0.248, 0.255, 0.468, 0.329, 
    0.363, 0.453, 0.453, 0.346, 0.363,
    0.363, 0.429851
]

poisson_distances = [
    0.611, 0.131, 0.131, 0.343, 0.220, 0.216,
    0.285, 0.288, 0.297, 0.644, 0.403,
    0.458, 0.615, 0.615, 0.430, 0.458,
    0.458, 0.722354
]

# Création du graphique
plt.figure(figsize=(10, 8))
plt.scatter(poisson_distances, p_distances)

# Tracer la ligne y = x
max_val = max(max(p_distances), max(poisson_distances))
plt.plot([0, max_val], [0, max_val], color='red', linestyle='--')

# Ajouter des labels et un titre
plt.title('Comparaison des distances évolutives')
plt.xlabel('Distance de Poisson')
plt.ylabel('p-distance')
plt.xlim(0, max_val)
plt.ylim(0, max_val)

# Ajouter des annotations pour chaque marqueur
for i in range(len(marqueurs)):
    plt.annotate(marqueurs[i], (poisson_distances[i], p_distances[i]), fontsize=9)

# Afficher le graphique
plt.grid()

# Enregistrer le graphique en tant qu'image PNG
plt.savefig('comparaison_distances_evolutives.png', format='png')

# Afficher le graphique
plt.show()
